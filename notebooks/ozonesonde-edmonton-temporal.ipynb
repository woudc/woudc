# %%
# %matplotlib inline

# %%
import datetime
import matplotlib.pyplot as plt
from pywoudc import WoudcClient

# connect to WOUDC data service
client = WoudcClient()

# get Edmonton sonde data from 1980 to present
gaw_id = 'EDT'
begin = datetime.date(1980, 1, 1)
end = datetime.date.today()

data = client.get_data('ozonesonde', property_name='gaw_id', property_value=gaw_id, temporal=[begin, end])

len(data['features'])
# Out:
# 1850

# %%
type(data['features'])
# Out:
# list

# %%
data['features'][0]
# Out:
# {u'geometry': {u'coordinates': [-114.1, 53.55], u'type': u'Point'},
#  u'properties': {u'agency': u'MSC',
#   u'data_payload_id': 41280,
#   u'flight_summary_correctioncode': u'',
#   u'flight_summary_correctionfactor': u'1',
#   u'flight_summary_instrument': u'',
#   u'flight_summary_integratedo3': u'341',
#   u'flight_summary_number': u'',
#   u'flight_summary_obstype': u'6',
#   u'flight_summary_sondetotalo3': u'',
#   u'flight_summary_totalo3': u'462',
#   u'flight_summary_wlcode': u'3',
#   u'gaw_id': u'EDT',
#   u'instance_datetime': u'1980/01/05 11:00:00+00',
#   u'instrument_model': u'UNKNOWN',
#   u'instrument_name': u'ecc',
#   u'instrument_number': u'UNKNOWN',
#   u'latest_observation': 0,
#   u'platform_id': u'021',
#   u'platform_name': u'Edmonton / Stony Plain',
#   u'platform_type': u'STN',
#   u'url': u'http://woudc.org/archive/Archive-NewFormat/OzoneSonde_1.0_1/stn021/ecc/1980/19800105.ECC.na.na.MSC.csv'},
#  u'type': u'Feature'}

# %%
# setup graph axes
x_axis = [datetime.datetime.strptime(x['properties']['instance_datetime'], '%Y/%m/%d %H:%M:%S+00') for x in data['features'] if x['properties']['flight_summary_totalo3']]
y_axis = [x['properties']['flight_summary_totalo3'] for x in data['features'] if x['properties']['flight_summary_totalo3']]

# render simple plot
print y_axis
plt.plot(x_axis, y_axis)
# Out:
# [u'462', u'353', u'373', u'373', u'387', u'401', u'419', u'419', u'406', u'457', u'411', u'455', u'392', u'336', u'356', u'377', u'360', u'358', u'419', u'390', u'352', u'364', u'322', u'357', u'342', u'322', u'325', u'322', u'340', u'276', u'327', u'321', u'277', u'329', u'352', u'332', u'297', u'313', u'349', u'382', u'392', u'351', u'386', u'408', u'416', u'339', u'415', u'385', u'432', u'436', u'372', u'379', u'407', u'366', u'366', u'351', u'355', u'360', u'374', u'389', u'369', u'354', u'365', u'343', u'350', u'340', u'325', u'284', u'300', u'320', u'261', u'247', u'326', u'325', u'302', u'243', u'313', u'256', u'318', u'314', u'372', u'340', u'336', u'331', u'409', u'464', u'392', u'412', u'325', u'397', u'489', u'433', u'412', u'363', u'490', u'392', u'321', u'465', u'447', u'458', u'473', u'383', u'366', u'441', u'371', u'357', u'390', u'374', u'344', u'337', u'320', u'346', u'346', u'317', u'327', u'313', u'301', u'349', u'272', u'299', u'266', u'319', u'308', u'313', u'256', u'289', u'354', u'328', u'360', u'365', u'358', u'407', u'364', u'370